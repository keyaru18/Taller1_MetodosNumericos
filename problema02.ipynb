# %% [markdown]
# # Algoritmo 2
#
# Implementación de Bubble Sort.
#
# - Args:
# arr (list): Lista a ordenar (debe contener elementos comparables)
#
# - Returns:
# list: Lista ordenada (la original es modificada in-place)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# * Vector 1

# %%
v1 = [3, 2, 5, 8, 4, 1] 
n = len(v1)
comparisons = 0
for i in range(n):
    swapped = False
    for j in range(1, n - i):
        comparisons += 1
        if v1[j] < v1[j - 1]:
            v1[j], v1[j - 1] = v1[j - 1], v1[j]
            swapped = True
    if not swapped:
        break
print("V_sorted:", v1)
print("Número de Comparaciones:", comparisons)
# Out:
# V_sorted: [1, 2, 3, 4, 5, 8]
# Número de Comparaciones: 15

# %% [markdown]
# * Vector 2

# %%
v2 = [-1, 0, 4, 5, 6, 7] 
n = len(v2)
comparisons = 0
for i in range(n):
    swapped = False
    for j in range(1, n - i):
        comparisons += 1
        if v2[j] < v2[j - 1]:
            v2[j], v2[j - 1] = v2[j - 1], v2[j]
            swapped = True
    if not swapped:
        break
print("V_sorted:", v2)
print("Número de Comparaciones:", comparisons)
# Out:
# V_sorted: [-1, 0, 4, 5, 6, 7]
# Número de Comparaciones: 5

# %%
import random

v3 = [random.randint(-200, 145) for _ in range(100)]

print("V_3:", v3)
comparisons = 0

n = len(v3)

for i in range(n):
    swapped = False
    for j in range(1, n - i):
        comparisons += 1
        if v3[j] < v3[j - 1]:
            v3[j], v3[j - 1] = v3[j - 1], v3[j]
            swapped = True
    if not swapped:
        break
print("V_sorted:", v3)
print("Número de Comparaciones:", comparisons)
# Out:
# V_3: [28, 41, -5, -36, 74, 71, -179, 26, 79, -2, -55, 69, -111, 54, 68, -105, -197, 2, 75, -102, -18, 110, -136, 16, -114, -173, 49, -9, -121, -116, 36, 102, 59, -159, 5, -178, 53, -67, 47, -139, 26, 114, 116, -32, -33, -161, -33, 76, -180, 24, 85, -12, 1, 32, 80, 69, 114, 10, -33, 93, 0, 122, 65, 136, -84, 79, 12, -99, -76, -63, -147, 121, 124, -1, -187, -2, -100, 101, -156, -113, -2, -76, 22, -113, -178, -152, 29, -100, -149, 132, -144, 131, -190, -188, -42, 25, 88, -67, 17, 90]
# V_sorted: [-197, -190, -188, -187, -180, -179, -178, -178, -173, -161, -159, -156, -152, -149, -147, -144, -139, -136, -121, -116, -114, -113, -113, -111, -105, -102, -100, -100, -99, -84, -76, -76, -67, -67, -63, -55, -42, -36, -33, -33, -33, -32, -18, -12, -9, -5, -2, -2, -2, -1, 0, 1, 2, 5, 10, 12, 16, 17, 22, 24, 25, 26, 26, 28, 29, 32, 36, 41, 47, 49, 53, 54, 59, 65, 68, 69, 69, 71, 74, 75, 76, 79, 79, 80, 85, 88, 90, 93, 101, 102, 110, 114, 114, 116, 121, 122, 124, 131, 132, 136]
# Número de Comparaciones: 4922

# %% [markdown]
# Modifique el Algoritmo y determine el número de comparaciones realizadas al ordenar la serie 54321

# %%
#    Modifique el Algoritmo y determine el número de comparaciones realizadas al ordenar la serie 54321

v4 = [5, 4, 3, 2, 1]
n = len(v4)
comparisons = 0
for i in range(n):
    swapped = False
    for j in range(1, n - i):
        comparisons += 1
        if v4[j] < v4[j - 1]:
            v4[j], v4[j - 1] = v4[j - 1], v4[j]
            swapped = True
    if not swapped:
        break

# %%
print("V_sorted:", v4)
print("Número de Comparaciones:", comparisons)
# Out:
# V_sorted: [1, 2, 3, 4, 5]
# Número de Comparaciones: 10
